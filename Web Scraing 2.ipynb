# %%
base_url='https://internetreviewer.net/'
import requests
from bs4 import BeautifulSoup

# %%
responce = requests.get(base_url)

# %%
html = responce.content

# %%
html
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 8]>    <html class="ie8" lang="en-US" prefix="og: http://ogp.me/ns#"> <![endif]-->\n<!--[if IE 9]>    <html class="ie9" lang="en-US" prefix="og: http://ogp.me/ns#"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)] lang="en-US" prefix="og: http://ogp.me/ns#"><![endif]-->\n<html lang="en-US" prefix="og: http://ogp.me/ns#">\n<head>\n<meta charset="utf-8" />\n<meta name=viewport content="width=device-width, initial-scale=1.0" />\n<!-- feeds & pingback -->\n<link rel="profile" href="http://gmpg.org/xfn/11" />\n<link rel="pingback" href="https://internetreviewer.net/xmlrpc.php" />\n<!--[if lt IE 9]><script src="https://internetreviewer.net/wp-content/themes/rehub/js/html5shiv.js"></script><![endif]-->\t\n<title>Internet Reviewer - Review Site</title>\n<script>(function(d, s, id){\n\t\t\t\t var js, fjs = d.getElementsByTagName(s)[0];\n\t\t\t\t if (d.getElementById(id)) {return;}\n\t\t\t\t js = d.createElement(s); js.id = id;\n\t\t\t\t js.src = "//connect.facebook.net/en_
# ...

# %%
soup = BeautifulSoup(html,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en-US" prefix="og: http://ogp.me/ns#"> <![endif]--><!--[if IE 9]>    <html class="ie9" lang="en-US" prefix="og: http://ogp.me/ns#"> <![endif]--><!--[if (gt IE 9)|!(IE)] lang="en-US" prefix="og: http://ogp.me/ns#"><![endif]--><html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- feeds & pingback -->
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://internetreviewer.net/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]><script src="https://internetreviewer.net/wp-content/themes/rehub/js/html5shiv.js"></script><![endif]-->
# <title>Internet Reviewer - Review Site</title>
# <script>(function(d, s, id){
# 				 var js, fjs = d.getElementsByTagName(s)[0];
# 				 if (d.getElementById(id)) {return;}
# 				 js = d.createElement(s); js.id = id;
# ...

# %%
divs =soup.findAll('div')
len(divs)
# Out:
# 230

# %%
title =soup.findAll('div',attrs={'class':'news-community clearfix'})

# %%
title
# Out:
# [<div class="news-community clearfix">
#  <div class="button_action">
#  <div class="floatleft mr5">
#  </div>
#  </div>
#  <div class="rh_grid_image_3_col">
#  <div class="rh_gr_img_first">
#  <figure>
#  <a href="https://internetreviewer.net/social-studio-review/">
#  <img alt="Social Studio Review" class="lazyimages" data-src="https://internetreviewer.net/wp-content/uploads/thumbs_dir/prodimage-13-1v9zbwr58133w25a7h1wc79awtk3we2jgs0f7hkmqpe4.png" height="160" src="https://internetreviewer.net/wp-content/themes/rehub/images/default/blank.gif" width="160"/> </a>
#  </figure>
#  </div>
#  <div class="rh_gr_top_middle">
#  <h2 class="font120 mt0 mb10 mobfont110 lineheight20 moblineheight15 mr30 pr20 "><a href="https://internetreviewer.net/social-studio-review/">Social Studio Review</a></h2>
#  <div class="meta post-meta mb5">
# ...

# %%
len(title)
# Out:
# 10

# %%
title[0]
# Out:
# <div class="news-community clearfix">
# <div class="button_action">
# <div class="floatleft mr5">
# </div>
# </div>
# <div class="rh_grid_image_3_col">
# <div class="rh_gr_img_first">
# <figure>
# <a href="https://internetreviewer.net/social-studio-review/">
# <img alt="Social Studio Review" class="lazyimages" data-src="https://internetreviewer.net/wp-content/uploads/thumbs_dir/prodimage-13-1v9zbwr58133w25a7h1wc79awtk3we2jgs0f7hkmqpe4.png" height="160" src="https://internetreviewer.net/wp-content/themes/rehub/images/default/blank.gif" width="160"/> </a>
# </figure>
# </div>
# <div class="rh_gr_top_middle">
# <h2 class="font120 mt0 mb10 mobfont110 lineheight20 moblineheight15 mr30 pr20 "><a href="https://internetreviewer.net/social-studio-review/">Social Studio Review</a></h2>
# <div class="meta post-meta mb5">
# ...

# %%
from selenium import webdriver

MAX_PAGE_NUM = 5
MAX_PAGE_DIG = 3
driver = webdriver.Firefox(executable_path=r'C:\Users\proxy_9k6gwyc\Downloads\geckodriver.exe')

with open('results.csv', 'w') as f:
    f.write("Buyer, Price \n")

for i in range(1, MAX_PAGE_NUM + 1):
    page_num = (MAX_PAGE_DIG - len(str(i))) * "0" + str(i)
    url = "http://econpy.pythonanywhere.com/ex/" + page_num + ".html"

    driver.get(url)

    buyers = driver.find_elements_by_xpath('//div[@title="buyer-name"]')
    prices = driver.find_elements_by_xpath('//span[@class="item-price"]')

    num_page_items = len(buyers)
    with open('results.csv', 'a') as f:
        for i in range(num_page_items):
            f.write(buyers[i].text + "," + prices[i].text + "\n")

driver.close()
